# %% [markdown]
# Stactics of Pass % of 3 Classes

# %%
import pandas as pd
from matplotlib import pyplot as plt

classdata = pd.read_csv('passcomp.csv')

print(classdata)
print(classdata.class_a)

plt.plot(classdata.class_a)
plt.plot(classdata.class_b)
plt.plot(classdata.class_c)

plt.title("Class PASS %")
plt.xticks([0,1,2,3,4,5], ["English", "Phy", "Chem", "Math","PDS","DS"])
plt.legend(['class A','class B','class C'])
# Out:
#    class_a  class_b  class_c  subs
# 0       50       70       69   Eng
# 1       43       54       56   phy
# 2       65       86       45  chem
# 3       56       34       23  math
# 4       23       54       45   pds
# 5       65       76       75    ds
# 0    50
# 1    43
# 2    65
# 3    56
# 4    23
# 5    65
# Name: class_a, dtype: int64
